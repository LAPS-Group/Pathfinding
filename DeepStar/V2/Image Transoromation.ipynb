# %%
import torchvision
from PIL import Image, ImageDraw

# %%
image_path = "Verification/kartdata.png"

img = Image.open(image_path)
t = transforms.Compose([
    transforms.Resize(size=512),
    transforms.CenterCrop(256),
    transforms.Grayscale(num_output_channels=1)
    ])

img = t(img)
#img.save("data/images/map.png")
#img.save("data/validation/map.png")
display(img)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FE159584B38>
